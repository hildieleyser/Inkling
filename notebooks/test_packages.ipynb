# %%
from load_emg_data import get_emg_data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from load_emg_data import get_emg_data
#
# ModuleNotFoundError: No module named 'load_emg_data'

# %%
emg_df = get_emg_data()
# Out:
# Accessing blob: EMG-nature/Clean_df/emg_trial_level_df.csv
# Downloaded 3078852 bytes from GCS
# Loaded DataFrame with shape: (4800, 8)

# %%
emg_df
# Out:
#       participant  day  block  trial_id  position  grasp  \
# 0               1    1      1         1         2      3
# 1               1    1      1         2         2      3
# 2               1    1      1         3         2      3
# 3               1    1      1         4         2      3
# 4               1    1      1         5         2      3
# ...           ...  ...    ...       ...       ...    ...
# 4795            8    2      2       146         9      2
# 4796            8    2      2       147         9      2
# 4797            8    2      2       148         9      2
# 4798            8    2      2       149         9      2
# 4799            8    2      2       150         9      2
#
#                                                  signal  \
# 0     [[3.763498e-05, 1.9842508e-05], [9.071698e-06,...
# 1     [[1.0537988e-05, 1.153949e-05], [1.18090165e-0...
# 2     [[1.6977565e-05, 1.9937088e-05], [2.1830994e-0...
# ...

# %%
from EMG_preprocess import preprocess_emg_fulltrial

# %%
X_train, X_test, y_train, y_test = preprocess_emg_fulltrial(emg_df)

# %%
X_train.shape
# Out:
# (1120, 10000, 16)

# %%
from emg_model import (
    build_emg_model,
    compile_emg_model,
    train_emg_model,
    evaluate_emg_model
)
# Out:
# 2025-12-05 12:36:39.287486: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-12-05 12:36:39.321986: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-12-05 12:36:39.322048: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-12-05 12:36:39.343619: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
input_shape = X_train.shape[1:]

# %%
model = build_emg_model(input_shape)

# %%
model = compile_emg_model(model)
