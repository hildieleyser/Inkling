# %%
import h5py
import numpy as np
import pandas as pd

# %%
file_path = 'EMG-nature_data_participant_1_participant1_day1_block1_emg_data (2).hdf5'

# %%
with h5py.File(file_path, "r") as f:
        list(f.keys())

# %%
emg_data = np.array(f[list(f.keys())[0]])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 emg_data = np.array(f[list(f.keys())[0]])
#
# File /opt/conda/lib/python3.10/_collections_abc.py:866, in MappingView.__len__(self)
#     865 def __len__(self):
# --> 866     return len(self._mapping)
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File /opt/conda/lib/python3.10/site-packages/h5py/_hl/group.py:504, in Group.__len__(self)
#     501 @with_phil
#     502 def __len__(self):
#     503     """ Number of members attached to this group """
# --> 504     return self.id.get_num_objs()
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5g.pyx:343, in h5py.h5g.GroupID.get_num_objs()
#
# ...
